# %% [markdown]
# # Generating a Micromodel Using an XCT Core
# ---
#
# This is an example notebook for creating a micromodel from start to finish. Optionally, ```svglib``` and ```reportlab``` can be used to convert the generated SVG file into a rasterized image, such as a PNG.
#
# **Developed by**:
# Aramy Truong, Postbachelors Research Associate - Terrestrial and Atmospheric Processes - Pacific Northwest National Laboratory, Richland, WA, USA.
#
# **Mentors**:
# Arunima Bhattacharjee and
# Maruti K. Mudunuru

# %%
# %pip install pore2chip
# Installing svglib and reportlab for exporting to a rasterized image format (does not come included in Pore2Chip requirements)
# %pip install svglib
# %pip install reportlab==3.6.13
# Out:
# Requirement already satisfied: pore2chip in /usr/local/lib/python3.11/dist-packages (0.1.1)
# Requirement already satisfied: drawsvg in /usr/local/lib/python3.11/dist-packages (from pore2chip) (2.4.0)
# Requirement already satisfied: ezdxf in /usr/local/lib/python3.11/dist-packages (from pore2chip) (1.3.5)
# Requirement already satisfied: feret in /usr/local/lib/python3.11/dist-packages (from pore2chip) (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pore2chip) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from pore2chip) (4.10.0.84)
# Requirement already satisfied: openpnm in /usr/local/lib/python3.11/dist-packages (from pore2chip) (3.5.0)
# Requirement already satisfied: porespy in /usr/local/lib/python3.11/dist-packages (from pore2chip) (2.4.2)
# Requirement already satisfied: pypardiso in /usr/local/lib/python3.11/dist-packages (from pore2chip) (0.4.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from pore2chip) (0.24.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pore2chip) (1.13.1)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from pore2chip) (0.43.0)
# Requirement already satisfied: svglib in /usr/local/lib/python3.11/dist-packages (from pore2chip) (1.5.1)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.11/dist-packages (from pore2chip) (3.6.13)
# Requirement already satisfied: cairosvg in /usr/local/lib/python3.11/dist-packages (from pore2chip) (2.7.1)
# Requirement already satisfied: gstools in /usr/local/lib/python3.11/dist-packages (from pore2chip) (1.6.1)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from pore2chip) (0.4.33)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from pore2chip) (0.4.33)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from pore2chip) (0.2.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pore2chip) (3.10.0)
# Requirement already satisfied: cairocffi in /usr/local/lib/python3.11/dist-packages (from cairosvg->pore2chip) (1.7.1)
# Requirement already satisfied: cssselect2 in /usr/local/lib/python3.11/dist-packages (from cairosvg->pore2chip) (0.7.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from cairosvg->pore2chip) (0.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from cairosvg->pore2chip) (11.1.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.11/dist-packages (from cairosvg->pore2chip) (1.4.0)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from ezdxf->pore2chip) (3.2.1)
# Requirement already satisfied: typing_extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ezdxf->pore2chip) (4.12.2)
# Requirement already satisfied: fonttools in /usr/local/lib/python3.11/dist-packages (from ezdxf->pore2chip) (4.55.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pore2chip) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pore2chip) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pore2chip) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pore2chip) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pore2chip) (2.8.2)
# Requirement already satisfied: emcee>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from gstools->pore2chip) (3.1.6)
# Requirement already satisfied: hankel>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gstools->pore2chip) (1.2.2)
# Requirement already satisfied: meshio>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from gstools->pore2chip) (5.3.5)
# Requirement already satisfied: pyevtk>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from gstools->pore2chip) (1.6.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax->pore2chip) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from jax->pore2chip) (3.4.0)
# Requirement already satisfied: chemicals in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (1.3.2)
# Requirement already satisfied: docrep in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (0.3.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (3.12.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (4.23.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (3.4.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (0.60.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (2.2.2)
# Requirement already satisfied: pyamg in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (5.2.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (13.9.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (1.13.1)
# Requirement already satisfied: thermo in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (0.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (4.67.1)
# Requirement already satisfied: transforms3d in /usr/local/lib/python3.11/dist-packages (from openpnm->pore2chip) (0.4.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from optax->pore2chip) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->pore2chip) (0.1.88)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->pore2chip) (1.11.0)
# Requirement already satisfied: dask in /usr/local/lib/python3.11/dist-packages (from porespy->pore2chip) (2024.10.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from porespy->pore2chip) (1.2.18)
# Requirement already satisfied: edt in /usr/local/lib/python3.11/dist-packages (from porespy->pore2chip) (2.4.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from porespy->pore2chip) (5.9.5)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.11/dist-packages (from porespy->pore2chip) (1.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from porespy->pore2chip) (75.1.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pore2chip) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pore2chip) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pore2chip) (0.4)
# Requirement already satisfied: mkl!=2024.0 in /usr/local/lib/python3.11/dist-packages (from pypardiso->pore2chip) (2025.0.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from svglib->pore2chip) (5.3.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->pore2chip) (4.3.6)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->pore2chip) (0.12.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from cssselect2->cairosvg->pore2chip) (0.5.1)
# Requirement already satisfied: mpmath>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from hankel>=1.0.0->gstools->pore2chip) (1.3.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl!=2024.0->pypardiso->pore2chip) (2025.0.4)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl!=2024.0->pypardiso->pore2chip) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl!=2024.0->pypardiso->pore2chip) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pore2chip) (1.17.0)
# Requirement already satisfied: cffi>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from cairocffi->cairosvg->pore2chip) (1.17.1)
# Requirement already satisfied: fluids>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from chemicals->openpnm->pore2chip) (1.1.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask->porespy->pore2chip) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask->porespy->pore2chip) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask->porespy->pore2chip) (2024.10.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask->porespy->pore2chip) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask->porespy->pore2chip) (6.0.2)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask->porespy->pore2chip) (8.6.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->porespy->pore2chip) (1.17.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->openpnm->pore2chip) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->openpnm->pore2chip) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->openpnm->pore2chip) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->openpnm->pore2chip) (0.22.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->openpnm->pore2chip) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openpnm->pore2chip) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->openpnm->pore2chip) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->openpnm->pore2chip) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->openpnm->pore2chip) (2.18.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.1.0->cairocffi->cairosvg->pore2chip) (2.22)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask->porespy->pore2chip) (3.21.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.4 in /usr/local/lib/python3.11/dist-packages (from intel-openmp>=2024->mkl!=2024.0->pypardiso->pore2chip) (2025.0.4)
# Requirement already satisfied: umf==0.9.* in /usr/local/lib/python3.11/dist-packages (from intel-cmplr-lib-ur==2025.0.4->intel-openmp>=2024->mkl!=2024.0->pypardiso->pore2chip) (0.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->openpnm->pore2chip) (0.1.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask->porespy->pore2chip) (1.0.0)
# Requirement already satisfied: svglib in /usr/local/lib/python3.11/dist-packages (1.5.1)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.11/dist-packages (from svglib) (3.6.13)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from svglib) (5.3.0)
# Requirement already satisfied: tinycss2>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from svglib) (1.4.0)
# Requirement already satisfied: cssselect2>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from svglib) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from cssselect2>=0.2.0->svglib) (0.5.1)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from reportlab->svglib) (11.1.0)
# Requirement already satisfied: reportlab==3.6.13 in /usr/local/lib/python3.11/dist-packages (3.6.13)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from reportlab==3.6.13) (11.1.0)

# %%
# !rm -r MONet_Pore2Chip_data
# !git clone https://github.com/aramyxt/MONet_Pore2Chip_data.git
# Out:
# Cloning into 'MONet_Pore2Chip_data'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 126 (delta 13), reused 117 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (126/126), 10.07 MiB | 18.11 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# Importing necessary libraries
from pore2chip import metrics, filter_im, coordination, generate, export
import cv2 as cv
import os
import copy
import numpy as np
from matplotlib import pyplot as plt

# Imported for basic visualization
import porespy as ps
import openpnm as op

from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM

path = os.getcwd()

# %% [markdown]
# ## Inputing Images and Filtering
# ---
# Here is an example for importing XCT images. Pore2Chip has functions for reading an array of images or reading images in a file directory for filtering. Both methods are below. NOTE: PoreSpy treats white pixels as pore space. Use the "invert" parameter to invert the filtered images,

# %% [markdown]
# ## Method 1:
# Read images externally and filter images using ```filter_im.filter```. If you already have images loaded in memory, this function will filter it using Otsu's filtering.

# %%
# Set up image path and 3D array to contain input images
image_path = r'MONet_Pore2Chip_data/data/bean_bucket_100/'
image_list_3D = np.zeros((100, 500, 500), dtype = np.uint8)

# Load image into each slice in 3D array
stride = 0
for file in sorted(os.listdir(image_path)):
    image = cv.imread(image_path + file, cv.IMREAD_GRAYSCALE)
    image_list_3D[stride,:,:] = copy.deepcopy(image)
    stride += 1

fig, ax = plt.subplots()
ax.imshow(image_list_3D[9,:,:], cmap='gray')

# %% [markdown]
# Here is where we filter the images from image data loaded in memory.

# %%
# Filter image and crop image down to 50 x 50, with a depth of 50
filtered_images = filter_im.filter_list(image_list_3D, [0, 50], [0, 50], 50, invert=True)
fig, ax = plt.subplots()
ax.imshow(filtered_images[3,:,:], cmap='gray')

# %% [markdown]
# ## Method 2:
# Input image path and filter using ```filter_im.read_and_filter_list```. This will load and filter the image files in one go. All parameters after the image_path variable are option. If no depth is given, All of the images in the directory will be loaded.

# %%
image_path = r'MONet_Pore2Chip_data/data/bean_bucket_100/'
# Reads and loads all images in the image_path string. This lines reads and filters a 50 x 50 x 50 3D image set
filtered_images = filter_im.read_and_filter_list(image_path, [0, 50], [0, 50], 50, invert=True)

fig, ax = plt.subplots()
ax.imshow(filtered_images[1,:,:], cmap='gray')

# %% [markdown]
# Whichever method you choose, you will have a 3D voxel binary image used to represent the solid and pore space. The cell below visualizes it using PoreSpy's visualization tools.

# %%
im_3d = ps.visualization.show_3D(filtered_images)
fig, ax = plt.subplots()
ax.imshow(im_3d, cmap=plt.cm.magma)

# %% [markdown]
# ## Getting Metrics
# ---
# To generate a micromodel, a list of pore diameters, throat diameters, and coordination numbers are required. To extract this information, use the ```metrics``` module.

# %% [markdown]
# These next couple code cells extracts pore and throat diameters and displays their distributions in a histogram.

# %%
# %%capture
# The capture command above stops Jupyter from print long outputs, includding HTML outputs from PoreSpy. It is optional
pore_diameters, throat_diameters = metrics.extract_diameters(filtered_images)
# Out:
# 0it [00:00, ?it/s]
#
# 26it [00:00, 244.91it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 21it [00:00, 196.15it/s]
# 25it [00:00, 238.74it/s]
# 0it [00:00, ?it/s]
# 26it [00:00, 255.64it/s]

# %%
# Plot Probability Densities
fig, ax = plt.subplots(1, 2)

ret = ax[0].hist(pore_diameters, density = True)
ret2 = ax[1].hist(throat_diameters, density = True)
ax[0].set_xlabel("Pore Diameter")
ax[0].set_ylabel("Probability Density")
ax[1].set_xlabel("Pore Throat Diameter")
ax[1].set_ylabel("Probability Density")
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# The next couple code cells extract the coordination numbers and displays their distributions as a histogram.

# %%
# %%capture
# Extracts coordination numbers
coordination_numbers = coordination.coordination_nums_3D(filtered_images)
coord_pdf = metrics.get_probability_density(coordination_numbers)

# %%
# Plot Probability Densities
fig, ax = plt.subplots()

ret = ax.hist(coordination_numbers, density = True)
ax.set_xlabel("Coordination Number")
ax.set_ylabel("Probability Density")
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ## Generating the Network
# ---
# In this example, a network is generated using a 10 x 10 pore structure (i.e. 10 pores on each size of the design). Pore diameters, throat diameters, and coordination numbers are required to generate. Their respective probability densities (that all add up to 1) are optional.

# %%
network = generate.generate_network(10, 10, pore_diameters, throat_diameters, coordination_numbers, coord_pdf=coord_pdf, center_channel=2)

h = op.visualization.plot_connections(network)
op.visualization.plot_coordinates(network, ax=h)

# %%
print(network)
# Out:
# ══════════════════════════════════════════════════════════════════════════════
# net : <openpnm.network.BodyCenteredCubic at 0x78a20d139df0>
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#   #  Properties                                                   Valid Values
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#   2  pore.coords                                                     181 / 181
#   3  throat.conns                                                    228 / 228
#   4  pore.coordination_number                                        181 / 181
#   5  pore.max_size                                                   181 / 181
#   6  pore.seed                                                       181 / 181
#   7  pore.diameter                                                   181 / 181
#   8  pore.volume                                                     181 / 181
#   9  throat.spacing                                                  191 / 228
#  10  throat.max_size                                                 191 / 228
#  11  throat.diameter                                                 228 / 228
#  12  throat.cross_sectional_area                                     191 / 228
#  13  throat.hydraulic_size_factors                                   191 / 228
#  14  throat.diffusive_size_factors                                   191 / 228
#  15  throat.lens_volume                                              191 / 228
#  16  throat.length                                                   191 / 228
#  17  throat.total_volume                                             191 / 228
#  18  throat.volume                                                   191 / 228
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#   #  Labels                                                 Assigned Locations
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#   2  pore.corner                                                           100
#   3  pore.body                                                              81
#   4  pore.surface                                                          100
#   5  pore.left                                                              10
#   6  pore.xmin                                                              10
#   7  pore.right                                                             10
#   8  pore.xmax                                                              10
#   9  pore.front                                                             10
#  10  pore.ymin                                                              10
#  11  pore.back                                                              10
#  12  pore.ymax                                                              10
#  13  pore.bottom                                                           100
#  14  pore.zmin                                                             100
#  15  pore.top                                                                0
#  16  pore.zmax                                                               0
#  17  pore.all                                                              181
#  18  throat.all                                                            228
#  19  throat.corner_to_body                                                 191
#  20  throat.corner_to_corner                                                 0
#  21  throat.body_to_body                                                     0
#  22  throat.new_conns                                                       30
#  23  throat.middle                                                           7
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――

# %%
gen_coord = op.models.network.coordination_number(network)

fig, ax = plt.subplots(1, 3, figsize=(16,4))
ret = ax[0].hist([coordination_numbers, gen_coord], density = True)
ret = ax[1].hist([pore_diameters, network['pore.diameter']], density = True)
ret = ax[2].hist([throat_diameters, network['throat.diameter']], density = True)

ax[0].set_xlabel('Coordination Number')
ax[0].set_ylabel('Probability Density')
ax[0].legend(['XCT Coordination', '10x10 Coordination'])
ax[1].set_xlabel('Pore Diameter (pixels)')
ax[1].set_ylabel('Probability Density')
ax[1].legend(['XCT Pore Diameter', '10x10 Pore Diameter'])
ax[2].set_xlabel('Throat Diameter (pixels)')
ax[2].set_ylabel('Probability Density')
ax[2].legend(['XCT Throat Diameter', '10x10 Throat Diameter'])

# %% [markdown]
# To save as either an SVG or DXF, use the ```export``` module. NOTE: The "design_size" parameter will decide the final unit width and height of the SVG image, but will also change the distance between pores. Use ```design_size = n * 20``` for the best results. In the example below, ```n = 10```, and so, ```design_size = 200```:

# %%
design = export.network2svg(network, 10, 10, 100, 100)

save_path = r'network.svg'

design.save_svg(save_path)

# %%
document = export.network2dxf(network)

save_path_dxf = os.path.dirname(path) + r'network.dxf'

document.saveas(save_path_dxf)

# %% [markdown]
# To write the SVG file as a rasterized image, we will use ```svglib``` and ```reportlab```:

# %%
rldrawing = svg2rlg('network.svg')
renderPM.drawToFile(rldrawing, 'network.png', fmt='PNG', dpi=200)
